# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
from seaborn import load_dataset

# %%
stock=pd.read_csv("stock_px.csv")
stock1=stock.head(100)
stock1
# Out:
#              Unnamed: 0    AA  AAPL    GE    IBM   JNJ  MSFT   PEP     SPX  \
# 0   1990-02-01 00:00:00  4.98  7.86  2.87  16.79  4.27  0.51  6.04  328.79
# 1   1990-02-02 00:00:00  5.04  8.00  2.87  16.89  4.37  0.51  6.09  330.92
# 2   1990-02-05 00:00:00  5.07  8.18  2.87  17.32  4.34  0.51  6.05  331.85
# 3   1990-02-06 00:00:00  5.01  8.12  2.88  17.56  4.32  0.51  6.15  329.66
# 4   1990-02-07 00:00:00  5.04  7.77  2.91  17.93  4.38  0.51  6.17  333.75
# ..                  ...   ...   ...   ...    ...   ...   ...   ...     ...
# 95  1990-06-19 00:00:00  5.31  9.31  3.29  20.88  5.16  0.82  7.76  358.47
# 96  1990-06-20 00:00:00  5.39  9.40  3.30  20.74  5.23  0.85  7.82  359.10
# 97  1990-06-21 00:00:00  5.39  9.84  3.30  20.94  5.39  0.84  7.86  360.47
# 98  1990-06-22 00:00:00  5.32  9.75  3.27  20.44  5.29  0.83  7.84  355.43
# 99  1990-06-25 00:00:00  5.29  9.69  3.27  20.50  5.24  0.81  7.75  352.31
#
#      XOM
# 0   6.12
# 1   6.24
# 2   6.25
# 3   6.23
# 4   6.33
# ...

# %% [markdown]
# # (1) NUMERICAL PLOTS

# %%
sns.set(style="dark")

# %%
sns.relplot(data=stock1,x="MSFT",y="AAPL")

# %%
diamond=pd.read_csv("diamonds.csv",index_col=[0])
diamond
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 1       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamond1=diamond.head(2000)

# %%
diamond1
# Out:
#       carat        cut color clarity  depth  table  price     x     y     z
# 1      0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2      0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3      0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4      0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5      0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...     ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 1996   0.52      Ideal     E    VVS1   61.8   55.0   3097  5.19  5.20  3.21
# 1997   0.53      Ideal     D    VVS1   61.6   55.0   3097  5.21  5.27  3.23
# 1998   1.29       Good     I      I1   64.2   54.0   3098  6.93  6.83  4.42
# 1999   0.90  Very Good     I     SI2   60.4   58.0   3099  6.25  6.31  3.79
# 2000   0.72      Ideal     D     VS2   61.8   57.0   3099  5.76  5.73  3.55
#
# [2000 rows x 10 columns]

# %%
sns.relplot(data=diamond1,x="cut",y="price")

# %%
sns.relplot(data=diamond1,x="cut",y="price",style="color")

# %%
sns.relplot(data=diamond1,x="cut",y="price",style="color",hue="carat")

# %%
iris=pd.read_csv("Iris (1).csv")

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
sns.relplot(data=iris,x='SepalLengthCm',y='SepalWidthCm',style='Species')

# %%
ds=pd.read_csv("ds_salaries.csv",index_col=[0])

# %%
ds
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
# ...

# %%
ds.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')
